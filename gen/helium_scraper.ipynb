# %%
import sys
import requests
from bs4 import BeautifulSoup
import unicodedata
import itertools
import itertools
import pprint
import re

URL = "https://arm-software.github.io/acle/mve_intrinsics/mve.html"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
intrinsics = [unicodedata.normalize('NFKD', code.text) for code in soup.select("tbody > tr > td:nth-child(1) > code")]
archs =  [unicodedata.normalize('NFKD', code.text) for code in soup.select("tbody > tr > td:nth-child(5) > code")]

decls = [' '.join(entry.split()).replace('( ', '(') for entry in intrinsics]

decl_archs = list(zip(decls, archs))

# %%
print(decl_archs)
# Out:
# [('float16x8_t [__arm_]vcreateq_f16(uint64_t a, uint64_t b)', 'MVE'), ('float32x4_t [__arm_]vcreateq_f32(uint64_t a, uint64_t b)', 'MVE'), ('int8x16_t [__arm_]vcreateq_s8(uint64_t a, uint64_t b)', 'MVE'), ('int16x8_t [__arm_]vcreateq_s16(uint64_t a, uint64_t b)', 'MVE'), ('int32x4_t [__arm_]vcreateq_s32(uint64_t a, uint64_t b)', 'MVE'), ('int64x2_t [__arm_]vcreateq_s64(uint64_t a, uint64_t b)', 'MVE'), ('uint8x16_t [__arm_]vcreateq_u8(uint64_t a, uint64_t b)', 'MVE'), ('uint16x8_t [__arm_]vcreateq_u16(uint64_t a, uint64_t b)', 'MVE'), ('uint32x4_t [__arm_]vcreateq_u32(uint64_t a, uint64_t b)', 'MVE'), ('uint64x2_t [__arm_]vcreateq_u64(uint64_t a, uint64_t b)', 'MVE'), ('uint8x16_t [__arm_]vddupq[_n]_u8(uint32_t a, const int imm)', 'MVE'), ('uint16x8_t [__arm_]vddupq[_n]_u16(uint32_t a, const int imm)', 'MVE'), ('uint32x4_t [__arm_]vddupq[_n]_u32(uint32_t a, const int imm)', 'MVE'), ('uint8x16_t [__arm_]vddupq[_wb]_u8(uint32_t *a, const int imm)', 'MVE'), ('uint16x8_t [__arm_]vddupq[_wb]_u16(uint32_t *a, const int imm)', 'MVE'), ('uint32x4_t [__arm_]vddupq[_wb]_u32(uint32_t *a, const int imm)', 'MVE'), ('uint8x16_t [__arm_]vddupq_m[_n_u8](uint8x16_t inactive, uint32_t a, const int imm, mve_pred16_t p)', 'MVE'), ('uint16x8_t [__arm_]vddupq_m[_n_u16](uint16x8_t inactive, uint32_t a, const int imm, mve_pred16_t p)', 'MVE'), ('uint32x4_t [__arm_]vddupq_m[_n_u32](uint32x4_t inactive, uint32_t a, const int imm, mve_pred16_t p)', 'MVE'), ('uint8x16_t [__arm_]vddupq_m[_wb_u8](uint8x16_t inactive, uint32_t *a, const int imm, mve_pred16_t p)', 'MVE'), ('uint16x8_t [__arm_]vddupq_m[_wb_u16](uint16x8_t inactive, uint32_t *a, const int imm, mve_pred16_t p)', 'MVE'), ('uint32x4_t [__arm_]vddupq_m[_wb_u32](uint32x4_t inactive, uint32_t *a, const int imm, mve_pred16_t p)', 'MVE'), ('uint8x16_t [__arm_]vddupq_x[_n]_u8(uint32_t a, const int imm, mve_pred16_t p)', 'MVE'), ('uint16x8_t [__arm_]vddupq_x[_n]_u16(uint32_t a, const int imm, mve_pred16_t p)', 'MVE'), ('uint32x4_t [__arm_]vddupq_x[_n]_u32(uint32_t a, const int imm, mve_pred16_t p)', 'MVE'), ('uint8x16_t [__arm_]vddupq_x[_wb]_u8(uint32_t *a, const int imm, mve_pred16_t p)', 'MVE'), ('uint16x8_t [__arm_]vddupq_x[_wb]_u16(uint32_t *a, const int imm, mve_pred16_t p)', 'MVE'), ('uint32x4_t [__arm_]vddupq_x[_wb]_u32(uint32_t *a, const int imm, mve_pred16_t p)', 'MVE'), ('uint8x16_t [__arm_]vdwdupq[_n]_u8(uint32_t a, uint32_t b, const int imm)', 'MVE'), ('uint16x8_t [__arm_]vdwdupq[_n]_u16(uint32_t a, uint32_t b, const int imm)', 'MVE'), ('uint32x4_t [__arm_]vdwdupq[_n]_u32(uint32_t a, uint32_t b, const int imm)', 'MVE'), ('uint8x16_t [__arm_]vdwdupq[_wb]_u8(uint32_t *a, uint32_t b, const int imm)', 'MVE'), ('uint16x8_t [__arm_]vdwdupq[_wb]_u16(uint32_t *a, uint32_t b, const int imm)', 'MVE'), ('uint32x4_t [__arm_]vdwdupq[_wb]_u32(uint32_t *a, uint32_t b, const int imm)', 'MVE'), ('uint8x16_t [__arm_]vdwdupq_m[_n_u8](uint8x16_t inactive, uint32_t a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint16x8_t [__arm_]vdwdupq_m[_n_u16](uint16x8_t inactive, uint32_t a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint32x4_t [__arm_]vdwdupq_m[_n_u32](uint32x4_t inactive, uint32_t a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint8x16_t [__arm_]vdwdupq_m[_wb_u8](uint8x16_t inactive, uint32_t *a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint16x8_t [__arm_]vdwdupq_m[_wb_u16](uint16x8_t inactive, uint32_t *a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint32x4_t [__arm_]vdwdupq_m[_wb_u32](uint32x4_t inactive, uint32_t *a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint8x16_t [__arm_]vdwdupq_x[_n]_u8(uint32_t a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint16x8_t [__arm_]vdwdupq_x[_n]_u16(uint32_t a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint32x4_t [__arm_]vdwdupq_x[_n]_u32(uint32_t a, uint32_t b, const int imm, mve_pred16_t p)', 'MVE'), ('uint8x16_t [__arm_]vdwdupq_x[_wb]_u8(uint32_t *a, uint32_t b, const  ...

# %%
def grouper(iterable, n, *, incomplete='fill', fillvalue=None):
    "Collect data into non-overlapping fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, fillvalue='x') --> ABC DEF Gxx
    # grouper('ABCDEFG', 3, incomplete='strict') --> ABC DEF ValueError
    # grouper('ABCDEFG', 3, incomplete='ignore') --> ABC DEF
    args = [iter(iterable)] * n
    if incomplete == 'fill':
        return itertools.zip_longest(*args, fillvalue=fillvalue)
    if incomplete == 'strict':
        return zip(*args, strict=True)
    if incomplete == 'ignore':
        return zip(*args)
    else:
        raise ValueError('Expected fill, strict, or ignore')

# %%
lengths = ["8", "16", "32", "64", "128", "256"]

def prefix_all(prefix, list):
  return [prefix + elem for elem in list]

types = {
  *prefix_all('u', lengths), # unsigned integers
  *prefix_all('s', lengths), # signed integers
  *prefix_all('f', lengths), # floating point
  *prefix_all('p', lengths), # polynomial
}


class MVEIdent:
  suffixes = ['q', # Q-register
              'w', # Widening, i.e one of the inputs is longer than the other and the output will be placed in a longer type
              'l'] # Long, i.e. the output type is twice as long as the inputs

  def __init__(self, func_name):
    self.scalar = False
    self.merging = False
    self.dontcare = False
    self.zero = False
    self.lane = False
    self.predicated = False
    self.write_back = False
    func_name = re.sub(r'\[.*?\]', '', func_name)
    parts = func_name.lstrip('_').split('_')

    if parts[0][0] == 'v':
      parts[0] = parts[0][1:] # remove first char

    if parts[0][-1] in MVEIdent.suffixes:
      self.suffix = parts[0][-1]
      if self.suffix == 'q':
        parts[0] = parts[0][:-1]
    else:
      self.suffix = None


    name_types = [type for type in parts if type in types]
    parts = [part for part in parts if part not in types]

    if len(name_types) == 1:
      [out_type, in_type] =  name_types * 2
    elif len(name_types) == 2:
      [out_type, in_type] = name_types
    else:
      [out_type, in_type] = [None, None]

    self.types = {'out' : out_type, 'in': in_type}

    if 'n' in parts:
      parts.remove('n')
      self.scalar = True
    if 'm' in parts:
      parts.remove('m')
      self.merging = True
    if 'x' in parts:
      parts.remove('x')
      self.dontcare = True
    if 'z' in parts:
      parts.remove('z')
      self.zero = True
    if 'p' in parts:
      parts.remove('p')
      self.predicated = True
    if 'wb' in parts:
      parts.remove('wb')
      self.write_back = True
    if 'lane' in parts:
      parts.remove('lane')
      self.lane = True

    self.name = '_'.join(parts)


  def __repr__(self):
    return f'NEON:{{ name: "{self.name}", suffix: {self.suffix}, types: {self.types}}}'

# %%
name_map = {
    # NEON
    "add": "add",
    "addl": "add_long",
    "addw": "add",
    "hadd": "add_halve",
    "rhadd": "add_halve_round",
    "addhn": "add_narrow_high",
    "raddhn": "add_round_narrow_high",
    "qadd": "add_saturate",
    "mul": "multiply",
    "mla": "multiply_add",
    "mls": "multiply_subtract",
    "mlal": "multiply_add_long",
    "mlsl": "multiply_subtract_long",
    "fma": "multiply_add_fused",
    "fms": "multiply_subtract_fused",
    "qdmulh": "multiply_double_saturate_high",
    "qrdmulh": "multiply_double_round_saturate_high",
    "qdmull": "multiply_double_saturate_long",
    "qdmlal": "multiply_double_add_saturate_long",
    "qdmlsl": "multiply_double_subtract_saturate_long",
    "mull": "multiply_long",
    "sub": "subtract",
    "subl": "subtract_long",
    "subw": "subtract",
    "hsub": "subtract_high",
    "subhn": "subtract_narrow_high",
    "rsubhn": "subtract_round_narrow_high",
    "qsub": "subtract_saturate",
    "abd": "subtract_abs",
    "abdl": "subtract_abs_long",
    "aba": "subtract_abs_add",
    "abal": "subtract_abs_add",
    "abs": "abs",
    "qabs": "abs_saturate",
    "max": "max",
    "min": "min",
    "recpe": "reciprocal_estimate",
    "recps": "reciprocal_step",
    "rsqrte": "reciprocal_sqrt_estimate",
    "rsqrts": "reciprocal_sqrt_step",
    "padd": "pairwise_add",
    "paddl": "pairwise_add_long",
    "padal": "pairwise_add_accumulate_long",
    "pmax": "pairwise_max",
    "pmin": "pairwise_min",
    "ce": "equal",
    "ceq": "equal",
    "cge": "greater_than_or_equal",
    "cle": "less_than_or_equal",
    "cgt": "greater_than",
    "clt": "less_than",
    "cage": "absolute_greater_than_or_equal",
    "cale": "absolute_less_than_or_equal",
    "cagt": "absolute_greater_than",
    "calt": "absolute_less_than",
    "tst": "compare_test_nonzero",
    "shl": "shift_left",
    "qshl": "shift_left_saturate",
    "qshlu": "shift_left_unsigned_saturate",
    "rshl": "shift_left_round",
    "qrshl": "shift_left_round_saturate",
    "shll": "shift_left_long",
    "sli": "shift_left_insert",
    "shr": "shift_right",
    "rshr": "shift_right_round",
    "sra": "shift_right_accumulate",
    "rsra": "shift_right_accumulate_round",
    "shrn": "shift_right_narrow",
    "qshrun": "shift_right_saturate_narrow_unsigned",
    "qshrn": "shift_right_saturate_narrow",
    "qrshrun": "shift_right_unsigned_saturate_narrow",
    "qrshrn": "shift_right_saturate_narrow",
    "rshrn": "shift_right_round_saturate_narrow",
    "sri": "shift_right_insert",
    "cvt": "convert",
    "reinterpret": "reinterpret",
    "movn": "move_narrow",
    "movn_high": "move_high_narrow",
    "movl": "move_long",
    "qmovn": "move_saturate_narrow",
    "qmovun": "move_unsigned_saturate_narrow",
    "neg": "negate",
    "qneg": "negate_saturate",
    "mvn": "bitwise_not",
    "and": "bitwise_and",
    "orr": "bitwise_or",
    "eor": "bitwise_xor",
    "orn": "bitwise_or_not",
    "cls": "count_leading_sign_bits",
    "clz": "count_leading_zero_bits",
    "cnt": "count_active_bits",
    "bic": "bitwise_clear",
    "bsl": "bitwise_select",
    "create": "create",
    "dup": "duplicate",
    "mov": "move",
    "combine": "combine",
    "get_high": "get_high",
    "get_low": "get_low",
    "get": "get",
    "ext": "extract",
    "rev64": "reverse_64bit",
    "rev32": "reverse_32bit",
    "rev16": "reverse_16bit",
    "zip": "zip",
    "uzp": "unzip",
    "trn": "transpose",
    "set": "set",
    "ld1": "load1",
    "ld1_dup": "load1_duplicate",
    "ld2": "load2",
    "ld3": "load3",
    "ld4": "load4",
    "ld2_dup": "load2_duplicate",
    "ld3_dup": "load3_duplicate",
    "ld4_dup": "load4_duplicate",
    "ld1_x2": "load1_x2",
    "ld1_x3": "load1_x3",
    "ld1_x4": "load1_x4",
    "st1": "store1",
    "st2": "store2",
    "st3": "store3",
    "st4": "store4",
    "st1_x2": "store1_x2",
    "st1_x3": "store1_x3",
    "st1_x4": "store1_x4",
    "tbl1": "table_lookup1",
    "tbl2": "table_lookup2",
    "tbl3": "table_lookup3",
    "tbl4": "table_lookup4",
    "tbx1": "table_extend1",
    "tbx2": "table_extend2",
    "tbx3": "table_extend3",
    "tbx4": "table_extend4",
    # A64
    "cadd_rot270": "complex_add_rotate_270",
    "cadd_rot90": "complex_add_rotate_90",
    "cmla": "complex_multiply_add",
    "cmla_rot270": "complex_multiply_add_rotate_270",
    "cmla_rot180": "complex_multiply_add_rotate_180",
    "cmla_rot90": "complex_multiply_add_rotate_90",
    "cvta": "convert_round_to_nearest_with_ties_away_from_zero",
    "cvtm": "convert_round_toward_negative_infinity",
    "cvtn": "convert_round_to_nearest_with_ties_to_even",
    "cvtp": "convert_round_toward_positive_infinity",
    "maxnm": "max",
    "minnm": "min",
    "rnd": "round",
    "rnda": "round_to_nearest_with_ties_away_from_zero",
    "rndm": "round_toward_negative_infinity",
    "rndn": "round_to_nearest_with_ties_to_even",
    "rndp": "round_toward_positive_infinity",
    "rndx": "round_inexact",
    # Helium only
    "abav": "absolute_subtract_add",
    "adc": "add_carry",
    "adci": "add_carry_initialized",
    "addlv": "reduce_add_long",
    "addlva": "reduce_add_long",
    "addv": "reduce_add",
    "addva": "reduce_add",
    "asrl": "shift_right_long_arithmetic",
    "brsr": "bit_reverse_shift_right",
    "cmpcs": "compare ",
    "cmpeq": "",
    "cmpge": "",
    "cmpgt": "",
    "cmphi": "",
    "cmple": "",
    "cmplt": "",
    "cmpne": "",
    "ctp16": "",
    "ctp32": "",
    "ctp64": "",
    "ctp8": "",
    "ddup": "",
    "dwdup": "",
    "hcadd_rot270": "",
    "hcadd_rot90": "",
    "idup": "",
    "iwdup": "",
    "ldrb": "",
    "ldrb_gather_offset": "",
    "ldrd_gather_base": "",
    "ldrd_gather_offset": "",
    "ldrd_gather_shifted_offset": "",
    "ldrh": "",
    "ldrh_gather_offset": "",
    "ldrh_gather_shifted_offset": "",
    "ldrw": "",
    "ldrw_gather_base": "",
    "ldrw_gather_offset": "",
    "ldrw_gather_shifted_offset": "",
    "lsll": "",
    "maxa": "",
    "maxav": "",
    "maxv": "",
    "mina": "",
    "minav": "",
    "minv": "",
    "mladav": "",
    "mladava": "",
    "mladavax": "",
    "mladavx": "",
    "mlaldav": "",
    "mlaldava": "",
    "mlaldavax": "",
    "mlaldavx": "",
    "mlas": "",
    "mlsdav": "",
    "mlsdava": "",
    "mlsdavax": "",
    "mlsdavx": "",
    "mlsldav": "",
    "mlsldava": "",
    "mlsldavax": "",
    "mlsldavx": "",
    "movlb": "",
    "movlt": "",
    "movnb": "",
    "movnt": "",
    "mulh": "",
    "mullb_int": "",
    "mullb_poly": "",
    "mullt_int": "",
    "mullt_poly": "",
    "pnot": "",
    "psel": "",
    "qdmladh": "",
    "qdmladhx": "",
    "qdmlah": "",
    "qdmlash": "",
    "qdmlsdh": "",
    "qdmlsdhx": "",
    "qdmullb": "",
    "qdmullt": "",
    "qmovnb": "",
    "qmovnt": "",
    "qmovunb": "",
    "qmovunt": "",
    "qrdmladh": "",
    "qrdmladhx": "",
    "qrdmlah": "",
    "qrdmlash": "",
    "qrdmlsdh": "",
    "qrdmlsdhx": "",
    "qrshrnb": "",
    "qrshrnt": "",
    "qrshrunb": "",
    "qrshrunt": "",
    "qshl_r": "",
    "qshrnb": "",
    "qshrnt": "",
    "qshrunb": "",
    "qshrunt": "",
    "rmlaldavh": "",
    "rmlaldavha": "",
    "rmlaldavhax": "",
    "rmlaldavhx": "",
    "rmlsldavh": "",
    "rmlsldavha": "",
    "rmlsldavhax": "",
    "rmlsldavhx": "",
    "rmulh": "",
    "rshrnb": "",
    "rshrnt": "",
    "sbc": "",
    "sbci": "",
    "shl_r": "",
    "shlc": "",
    "shllb": "",
    "shllt": "",
    "shrnb": "",
    "shrnt": "",
    "sqrshr": "",
    "sqrshrl": "",
    "sqrshrl_sat48": "",
    "sqshl": "",
    "sqshll": "",
    "srshr": "",
    "srshrl": "",
    "strb": "",
    "strb_scatter_offset": "",
    "strd_scatter_base": "",
    "strd_scatter_offset": "",
    "strd_scatter_shifted_offset": "",
    "strh": "",
    "strh_scatter_offset": "",
    "strh_scatter_shifted_offset": "",
    "strw": "",
    "strw_scatter_base": "",
    "strw_scatter_offset": "",
    "strw_scatter_shifted_offset": "",
    "uninitialized": "",
    "uqrshl": "",
    "uqrshll": "",
    "uqrshll_sat48": "",
    "uqshl": "",
    "uqshll": "",
    "urshr": "",
    "urshrl": "",
}

# %%
import functools


type_order = [
  "uint8x8_t",
  "uint8x16_t",
  "int8x8_t",
  "int8x16_t",
  "uint16x4_t",
  "uint16x8_t",
  "int16x4_t",
  "int16x8_t",
  "uint32x2_t",
  "uint32x4_t",
  "int32x2_t",
  "int32x4_t",
  "uint64x1_t",
  "uint64x2_t",
  "uint32x2_t",
  "uint32x4_t",
  "float16x4_t",
  "float16x8_t",
  "float32x2_t",
  "float32x4_t",
  "poly8x8_t",
  "poly16x4_t",
  'mve_pred16_t',
]

class Var:
  type_map = { key:value for (value,key) in enumerate(type_order) }

  def __init__(self, string):
    components = string.split()
    self.ident = components.pop(-1)
    self.type = ' '.join(components)

  def __str__(self):
    return f"{self.type} {self.ident}"

  def __repr__(self):
    return f'Var:{{ type: "{self.type}", ident: "{self.ident}"}}'

  def __eq__(self, other):
    if self.type in Var.type_map and other.type in Var.type_map:
      return Var.type_map[self.type] == Var.type_map[other.type]
    else:
      return False

  def __lt__(self, other):
    if self.type in Var.type_map and other.type in Var.type_map:
      return Var.type_map[self.type] < Var.type_map[other.type]
    elif self.type in Var.type_map and other.type not in Var.type_map:
      return True
    else:
      return False

class Function:
  def __init__(self, decl_arch):
    (decl, arch) = decl_arch
    self.decl = decl
    in_parens = r"\((.)+\)"
    args = re.search(in_parens, decl).group().removeprefix('(').removesuffix(')')
    decl = re.sub(in_parens, '', decl).split()
    self.return_type = decl.pop(0)
    self.intrinsic = decl.pop(0)
    self.intrinsic = self.intrinsic.replace('[__arm_]', '')
    self.args = [Var(arg) for arg in args.split(',')]
    self.decoded = MVEIdent(self.intrinsic)
    self.intrinsic = re.sub(r'[\[\]]', '', self.intrinsic)
    self.archs = arch.split('/')
    if self.args[-1].type == "const int":
      self.const = self.args[-1].ident
      self.args = self.args[:-1]
    else:
      self.const = None
    self.name = name_map[self.decoded.name] if self.decoded.name in name_map else self.decoded.name
    if self.decoded.lane:
      self.name += '_lane'


  def __repr__(self):
    return f'Function:{{ intrinsic: "{self.intrinsic}", decoded: {self.decoded}, return_type: "{self.return_type}", args: "{self.args}" }}'

  def __equal__(self, other):
    var_match = [arg1 == arg2 for (arg1, arg2) in zip(self.args, other.args)]
    return functools.reduce(lambda a,b: a and b, var_match)

  def __lt__(self, other):
    for (arg1, arg2) in zip(self.args, other.args):
      if arg1 == arg2:
        continue
      else:
        return arg1 < arg2
    return False

# %%
funcs = [Function(decl_arch) for decl_arch in decl_archs]
import pprint
pprint.pp(funcs)
# Out:
# [Function:{ intrinsic: "vcreateq_f16", decoded: NEON:{ name: "create", suffix: q, types: {'out': 'f16', 'in': 'f16'}}, return_type: "float16x8_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_f32", decoded: NEON:{ name: "create", suffix: q, types: {'out': 'f32', 'in': 'f32'}}, return_type: "float32x4_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_s8", decoded: NEON:{ name: "create", suffix: q, types: {'out': 's8', 'in': 's8'}}, return_type: "int8x16_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_s16", decoded: NEON:{ name: "create", suffix: q, types: {'out': 's16', 'in': 's16'}}, return_type: "int16x8_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_s32", decoded: NEON:{ name: "create", suffix: q, types: {'out': 's32', 'in': 's32'}}, return_type: "int32x4_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_s64", decoded: NEON:{ name: "create", suffix: q, types: {'out': 's64', 'in': 's64'}}, return_type: "int64x2_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_u8", decoded: NEON:{ name: "create", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_u16", decoded: NEON:{ name: "create", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_u32", decoded: NEON:{ name: "create", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcreateq_u64", decoded: NEON:{ name: "create", suffix: q, types: {'out': 'u64', 'in': 'u64'}}, return_type: "uint64x2_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64_t", ident: "b"}]" },
#  Function:{ intrinsic: "vddupq_n_u8", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vddupq_n_u16", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vddupq_n_u32", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vddupq_wb_u8", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}]" },
#  Function:{ intrinsic: "vddupq_wb_u16", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}]" },
#  Function:{ intrinsic: "vddupq_wb_u32", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}]" },
#  Function:{ intrinsic: "vddupq_m_n_u8", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_m_n_u16", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_m_n_u32", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_m_wb_u8", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_m_wb_u16", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_m_wb_u32", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_x_n_u8", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_x_n_u16", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_x_n_u32", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_x_wb_u8", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_x_wb_u16", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vddupq_x_wb_u32", decoded: NEON:{ name: "ddup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_n_u8", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "vdwdupq_n_u16", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "vdwdupq_n_u32", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "vdwdupq_wb_u8", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "vdwdupq_wb_u16", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "vdwdupq_wb_u32", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "vdwdupq_m_n_u8", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_m_n_u16", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_m_n_u32", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_m_wb_u8", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_m_wb_u16", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_m_wb_u32", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_x_n_u8", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_x_n_u16", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_x_n_u32", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_x_wb_u8", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_x_wb_u16", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdwdupq_x_wb_u32", decoded: NEON:{ name: "dwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_n_u8", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vidupq_n_u16", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vidupq_n_u32", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vidupq_wb_u8", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}]" },
#  Function:{ intrinsic: "vidupq_wb_u16", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}]" },
#  Function:{ intrinsic: "vidupq_wb_u32", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}]" },
#  Function:{ intrinsic: "vidupq_m_n_u8", decoded: NEON:{ name: "idup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_m_n_u16", decoded: NEON:{ name: "idup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_m_n_u32", decoded: NEON:{ name: "idup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_m_wb_u8", decoded: NEON:{ name: "idup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_m_wb_u16", decoded: NEON:{ name: "idup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_m_wb_u32", decoded: NEON:{ name: "idup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_x_n_u8", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_x_n_u16", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_x_n_u32", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_x_wb_u8", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_x_wb_u16", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vidupq_x_wb_u32", decoded: NEON:{ name: "idup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_n_u8", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "viwdupq_n_u16", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "viwdupq_n_u32", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "viwdupq_wb_u8", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "viwdupq_wb_u16", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "viwdupq_wb_u32", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}]" },
#  Function:{ intrinsic: "viwdupq_m_n_u8", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_m_n_u16", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_m_n_u32", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_m_wb_u8", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_m_wb_u16", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_m_wb_u32", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_x_n_u8", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_x_n_u16", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_x_n_u32", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_x_wb_u8", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_x_wb_u16", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "viwdupq_x_wb_u32", decoded: NEON:{ name: "iwdup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "*a"}, Var:{ type: "uint32_t", ident: "b"}, Var:{ type: "const int", ident: "imm"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_n_s8", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 's8', 'in': 's8'}}, return_type: "int8x16_t", args: "[Var:{ type: "int8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_n_s16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 's16', 'in': 's16'}}, return_type: "int16x8_t", args: "[Var:{ type: "int16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_n_s32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 's32', 'in': 's32'}}, return_type: "int32x4_t", args: "[Var:{ type: "int32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_n_u8", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_n_u16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_n_u32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_n_f16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'f16', 'in': 'f16'}}, return_type: "float16x8_t", args: "[Var:{ type: "float16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_n_f32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'f32', 'in': 'f32'}}, return_type: "float32x4_t", args: "[Var:{ type: "float32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vdupq_m_n_s8", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "inactive"}, Var:{ type: "int8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_m_n_s16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "inactive"}, Var:{ type: "int16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_m_n_s32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32x4_t", args: "[Var:{ type: "int32x4_t", ident: "inactive"}, Var:{ type: "int32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_m_n_u8", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_m_n_u16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_m_n_u32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_m_n_f16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "inactive"}, Var:{ type: "float16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_m_n_f32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32x4_t", args: "[Var:{ type: "float32x4_t", ident: "inactive"}, Var:{ type: "float32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_s8", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 's8', 'in': 's8'}}, return_type: "int8x16_t", args: "[Var:{ type: "int8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_s16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 's16', 'in': 's16'}}, return_type: "int16x8_t", args: "[Var:{ type: "int16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_s32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 's32', 'in': 's32'}}, return_type: "int32x4_t", args: "[Var:{ type: "int32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_u8", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_u16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_u32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_f16", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'f16', 'in': 'f16'}}, return_type: "float16x8_t", args: "[Var:{ type: "float16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vdupq_x_n_f32", decoded: NEON:{ name: "dup", suffix: q, types: {'out': 'f32', 'in': 'f32'}}, return_type: "float32x4_t", args: "[Var:{ type: "float32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev16q_s8", decoded: NEON:{ name: "rev16", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev16q_u8", decoded: NEON:{ name: "rev16", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev16q_m_s8", decoded: NEON:{ name: "rev16", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "inactive"}, Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev16q_m_u8", decoded: NEON:{ name: "rev16", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev16q_x_s8", decoded: NEON:{ name: "rev16", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev16q_x_u8", decoded: NEON:{ name: "rev16", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_s8", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev32q_s16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev32q_u8", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev32q_u16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev32q_f16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev32q_m_s8", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "inactive"}, Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_m_s16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "inactive"}, Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_m_u8", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_m_u16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_m_f16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "inactive"}, Var:{ type: "float16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_x_s8", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_x_s16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_x_u8", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_x_u16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev32q_x_f16", decoded: NEON:{ name: "rev32", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_s8", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_s16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_s32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32x4_t", args: "[Var:{ type: "int32x4_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_u8", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_u16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_u32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_f16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_f32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32x4_t", args: "[Var:{ type: "float32x4_t", ident: "a"}]" },
#  Function:{ intrinsic: "vrev64q_m_s8", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "inactive"}, Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_m_s16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "inactive"}, Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_m_s32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32x4_t", args: "[Var:{ type: "int32x4_t", ident: "inactive"}, Var:{ type: "int32x4_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_m_u8", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "inactive"}, Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_m_u16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "inactive"}, Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_m_u32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "inactive"}, Var:{ type: "uint32x4_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_m_f16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "inactive"}, Var:{ type: "float16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_m_f32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32x4_t", args: "[Var:{ type: "float32x4_t", ident: "inactive"}, Var:{ type: "float32x4_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_s8", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_s16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_s32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32x4_t", args: "[Var:{ type: "int32x4_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_u8", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_u16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_u32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_f16", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vrev64q_x_f32", decoded: NEON:{ name: "rev64", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32x4_t", args: "[Var:{ type: "float32x4_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vgetq_lane_f16", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16_t", args: "[Var:{ type: "float16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_f32", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32_t", args: "[Var:{ type: "float32x4_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_s8", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8_t", args: "[Var:{ type: "int8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_s16", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16_t", args: "[Var:{ type: "int16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_s32", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32_t", args: "[Var:{ type: "int32x4_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_s64", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "int64_t", args: "[Var:{ type: "int64x2_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_u8", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_u16", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_u32", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32_t", args: "[Var:{ type: "uint32x4_t", ident: "a"}]" },
#  Function:{ intrinsic: "vgetq_lane_u64", decoded: NEON:{ name: "get", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint64_t", args: "[Var:{ type: "uint64x2_t", ident: "a"}]" },
#  Function:{ intrinsic: "vsetq_lane_f16", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16_t", ident: "a"}, Var:{ type: "float16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_f32", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32x4_t", args: "[Var:{ type: "float32_t", ident: "a"}, Var:{ type: "float32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_s8", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8_t", ident: "a"}, Var:{ type: "int8x16_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_s16", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_s32", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32x4_t", args: "[Var:{ type: "int32_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_s64", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "int64x2_t", args: "[Var:{ type: "int64_t", ident: "a"}, Var:{ type: "int64x2_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_u8", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8_t", ident: "a"}, Var:{ type: "uint8x16_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_u16", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_u32", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vsetq_lane_u64", decoded: NEON:{ name: "set", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint64x2_t", args: "[Var:{ type: "uint64_t", ident: "a"}, Var:{ type: "uint64x2_t", ident: "b"}]" },
#  Function:{ intrinsic: "vuninitializedq_s8", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 's8', 'in': 's8'}}, return_type: "int8x16_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_s16", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 's16', 'in': 's16'}}, return_type: "int16x8_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_s32", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 's32', 'in': 's32'}}, return_type: "int32x4_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_s64", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 's64', 'in': 's64'}}, return_type: "int64x2_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_u8", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 'u8', 'in': 'u8'}}, return_type: "uint8x16_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_u16", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 'u16', 'in': 'u16'}}, return_type: "uint16x8_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_u32", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 'u32', 'in': 'u32'}}, return_type: "uint32x4_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_u64", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 'u64', 'in': 'u64'}}, return_type: "uint64x2_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_f16", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 'f16', 'in': 'f16'}}, return_type: "float16x8_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq_f32", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': 'f32', 'in': 'f32'}}, return_type: "float32x4_t", args: "[Var:{ type: "", ident: "void"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32x4_t", args: "[Var:{ type: "int32x4_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "int64x2_t", args: "[Var:{ type: "int64x2_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint64x2_t", args: "[Var:{ type: "uint64x2_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "t"}]" },
#  Function:{ intrinsic: "vuninitializedq", decoded: NEON:{ name: "uninitialized", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32x4_t", args: "[Var:{ type: "float32x4_t", ident: "t"}]" },
#  Function:{ intrinsic: "vcmpeqq_f16", decoded: NEON:{ name: "cmpeq", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "float16x8_t", ident: "a"}, Var:{ type: "float16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcmpeqq_f32", decoded: NEON:{ name: "cmpeq", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "float32x4_t", ident: "a"}, Var:{ type: "float32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vcmpeqq_s8", decoded: NEON:{ name: "cmpeq", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int8x16_t", ident: "b"}]" },
# ...
#  Function:{ intrinsic: "vmovnbq_u32", decoded: NEON:{ name: "movnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vmovnbq_m_s16", decoded: NEON:{ name: "movnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vmovnbq_m_s32", decoded: NEON:{ name: "movnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vmovnbq_m_u16", decoded: NEON:{ name: "movnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vmovnbq_m_u32", decoded: NEON:{ name: "movnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vmovntq_s16", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vmovntq_s32", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vmovntq_u16", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vmovntq_u32", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vmovntq_m_s16", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vmovntq_m_s32", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vmovntq_m_u16", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vmovntq_m_u32", decoded: NEON:{ name: "movnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovnbq_s16", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovnbq_s32", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovnbq_u16", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovnbq_u32", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovnbq_m_s16", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovnbq_m_s32", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovnbq_m_u16", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovnbq_m_u32", decoded: NEON:{ name: "qmovnb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovntq_s16", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovntq_s32", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovntq_u16", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovntq_u32", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovntq_m_s16", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovntq_m_s32", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovntq_m_u16", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovntq_m_u32", decoded: NEON:{ name: "qmovnt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovunbq_s16", decoded: NEON:{ name: "qmovunb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovunbq_s32", decoded: NEON:{ name: "qmovunb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovunbq_m_s16", decoded: NEON:{ name: "qmovunb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovunbq_m_s32", decoded: NEON:{ name: "qmovunb", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovuntq_s16", decoded: NEON:{ name: "qmovunt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovuntq_s32", decoded: NEON:{ name: "qmovunt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}]" },
#  Function:{ intrinsic: "vqmovuntq_m_s16", decoded: NEON:{ name: "qmovunt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vqmovuntq_m_s32", decoded: NEON:{ name: "qmovunt", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpnot", decoded: NEON:{ name: "pnot", suffix: None, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "mve_pred16_t", ident: "a"}]" },
#  Function:{ intrinsic: "vpselq_s8", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "int8x16_t", args: "[Var:{ type: "int8x16_t", ident: "a"}, Var:{ type: "int8x16_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_s16", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "int16x8_t", args: "[Var:{ type: "int16x8_t", ident: "a"}, Var:{ type: "int16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_s32", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "int32x4_t", args: "[Var:{ type: "int32x4_t", ident: "a"}, Var:{ type: "int32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_s64", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "int64x2_t", args: "[Var:{ type: "int64x2_t", ident: "a"}, Var:{ type: "int64x2_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_u8", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint8x16_t", args: "[Var:{ type: "uint8x16_t", ident: "a"}, Var:{ type: "uint8x16_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_u16", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint16x8_t", args: "[Var:{ type: "uint16x8_t", ident: "a"}, Var:{ type: "uint16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_u32", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint32x4_t", args: "[Var:{ type: "uint32x4_t", ident: "a"}, Var:{ type: "uint32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_u64", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "uint64x2_t", args: "[Var:{ type: "uint64x2_t", ident: "a"}, Var:{ type: "uint64x2_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_f16", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "float16x8_t", args: "[Var:{ type: "float16x8_t", ident: "a"}, Var:{ type: "float16x8_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vpselq_f32", decoded: NEON:{ name: "psel", suffix: q, types: {'out': None, 'in': None}}, return_type: "float32x4_t", args: "[Var:{ type: "float32x4_t", ident: "a"}, Var:{ type: "float32x4_t", ident: "b"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vctp8q", decoded: NEON:{ name: "ctp8", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vctp16q", decoded: NEON:{ name: "ctp16", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vctp32q", decoded: NEON:{ name: "ctp32", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vctp64q", decoded: NEON:{ name: "ctp64", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}]" },
#  Function:{ intrinsic: "vctp8q_m", decoded: NEON:{ name: "ctp8", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vctp16q_m", decoded: NEON:{ name: "ctp16", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vctp32q_m", decoded: NEON:{ name: "ctp32", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "vctp64q_m", decoded: NEON:{ name: "ctp64", suffix: q, types: {'out': None, 'in': None}}, return_type: "mve_pred16_t", args: "[Var:{ type: "uint32_t", ident: "a"}, Var:{ type: "mve_pred16_t", ident: "p"}]" },
#  Function:{ intrinsic: "lsll", decoded: NEON:{ name: "lsll", suffix: l, types: {'out': None, 'in': None}}, return_type: "uint64_t", args: "[Var:{ type: "uint64_t", ident: "value"}, Var:{ type: "int32_t", ident: "shift"}]" },
#  Function:{ intrinsic: "asrl", decoded: NEON:{ name: "asrl", suffix: l, types: {'out': None, 'in': None}}, return_type: "int64_t", args: "[Var:{ type: "int64_t", ident: "value"}, Var:{ type: "int32_t", ident: "shift"}]" },
#  Function:{ intrinsic: "sqrshrl", decoded: NEON:{ name: "sqrshrl", suffix: l, types: {'out': None, 'in': None}}, return_type: "int64_t", args: "[Var:{ type: "int64_t", ident: "value"}, Var:{ type: "int32_t", ident: "shift"}]" },
#  Function:{ intrinsic: "sqrshrl_sat48", decoded: NEON:{ name: "sqrshrl_sat48", suffix: l, types: {'out': None, 'in': None}}, return_type: "int64_t", args: "[Var:{ type: "int64_t", ident: "value"}, Var:{ type: "int32_t", ident: "shift"}]" },
#  Function:{ intrinsic: "sqrshr", decoded: NEON:{ name: "sqrshr", suffix: None, types: {'out': None, 'in': None}}, return_type: "int32_t", args: "[Var:{ type: "int32_t", ident: "value"}, Var:{ type: "int32_t", ident: "shift"}]" },
#  Function:{ intrinsic: "urshrl", decoded: NEON:{ name: "urshrl", suffix: l, types: {'out': None, 'in': None}}, return_type: "uint64_t", args: "[Var:{ type: "uint64_t", ident: "value"}]" },
#  Function:{ intrinsic: "srshrl", decoded: NEON:{ name: "srshrl", suffix: l, types: {'out': None, 'in': None}}, return_type: "int64_t", args: "[Var:{ type: "int64_t", ident: "value"}]" },
#  Function:{ intrinsic: "urshr", decoded: NEON:{ name: "urshr", suffix: None, types: {'out': None, 'in': None}}, return_type: "uint32_t", args: "[Var:{ type: "uint32_t", ident: "value"}]" },
#  Function:{ intrinsic: "srshr", decoded: NEON:{ name: "srshr", suffix: None, types: {'out': None, 'in': None}}, return_type: "int32_t", args: "[Var:{ type: "int32_t", ident: "value"}]" }]

# %%
neon_funcs = [f for f in funcs if "NEON" in f.archs]  # Filter architecture
neon_int_funcs = [
    f
    for f in neon_funcs
    if "float" not in f.return_type and not any(["float" in arg.type for arg in f.args])
]
neon_float_funcs = [
    f
    for f in neon_funcs
    if "float" in f.return_type or any(["float" in arg.type for arg in f.args])
]

helium_funcs = [f for f in funcs if not "NEON" in f.archs]  # Filter architecture
helium_int_funcs = [
    f
    for f in helium_funcs
    if "float" not in f.return_type and not any(["float" in arg.type for arg in f.args])
]
helium_float_funcs = [
    f
    for f in helium_funcs
    if "float" in f.return_type or any(["float" in arg.type for arg in f.args])
]

# %%
import pprint
names = [f.name for f in helium_int_funcs]
pprint.pp(list(dict.fromkeys(names)))
# Out:
# ['create',
#  'ddup',
#  'dwdup',
#  'idup',
#  'iwdup',
#  'duplicate',
#  'reverse_16bit',
#  'reverse_32bit',
#  'reverse_64bit',
#  'uninitialized',
#  'cmpeq',
#  'cmpne',
#  'cmpge',
#  'cmpcs',
#  'cmpgt',
#  'cmphi',
#  'cmple',
#  'cmplt',
#  'min',
#  'mina',
#  'minv',
#  'minav',
#  'max',
#  'maxa',
#  'maxv',
#  'maxav',
#  'abav',
#  'subtract_abs',
#  'abs',
#  'abs_saturate',
#  'adci',
#  'adc',
#  'add',
#  'addlva',
#  'addlv',
#  'addva',
#  'addv',
#  'add_halve',
#  'add_halve_round',
#  'add_saturate',
#  'mulh',
#  'mullb_poly',
#  'mullb_int',
#  'mullt_poly',
#  'mullt_int',
#  'multiply',
#  'rmulh',
#  'qdmladh',
#  'qdmladhx',
#  'qrdmladh',
#  'qrdmladhx',
#  'qdmlah',
#  'qrdmlah',
#  'qdmlash',
#  'qrdmlash',
#  'qdmlsdh',
#  'qdmlsdhx',
#  'qrdmlsdh',
#  'qrdmlsdhx',
#  'multiply_double_saturate_high',
#  'multiply_double_round_saturate_high',
#  'qdmullb',
#  'qdmullt',
#  'mladava',
#  'mladav',
#  'mladavax',
#  'mladavx',
#  'mlaldava',
#  'mlaldav',
#  'mlaldavax',
#  'mlaldavx',
#  'multiply_add',
#  'mlas',
#  'mlsdava',
#  'mlsdav',
#  'mlsdavax',
#  'mlsdavx',
#  'mlsldava',
#  'mlsldav',
#  'mlsldavax',
#  'mlsldavx',
#  'rmlaldavha',
#  'rmlaldavh',
#  'rmlaldavhax',
#  'rmlaldavhx',
#  'rmlsldavha',
#  'rmlsldavh',
#  'rmlsldavhax',
#  'rmlsldavhx',
#  'sbci',
#  'sbc',
#  'subtract',
#  'subtract_high',
#  'subtract_saturate',
#  'count_leading_sign_bits',
#  'count_leading_zero_bits',
#  'bitwise_clear',
#  'negate',
#  'negate_saturate',
#  'bitwise_and',
#  'bitwise_xor',
#  'bitwise_not',
#  'bitwise_or_not',
#  'bitwise_or',
#  'complex_add_rotate_90',
#  'complex_add_rotate_270',
#  'hcadd_rot90',
#  'hcadd_rot270',
#  'load2',
#  'load4',
#  'load1',
#  'ldrb',
#  'ldrh',
#  'ldrw',
#  'ldrh_gather_offset',
#  'ldrh_gather_shifted_offset',
#  'ldrb_gather_offset',
#  'ldrw_gather_offset',
#  'ldrw_gather_shifted_offset',
#  'ldrw_gather_base',
#  'ldrd_gather_offset',
#  'ldrd_gather_shifted_offset',
#  'ldrd_gather_base',
#  'store2',
#  'store4',
#  'store1',
#  'strb',
#  'strh',
#  'strw',
#  'strb_scatter_offset',
#  'strh_scatter_offset',
#  'strh_scatter_shifted_offset',
#  'strw_scatter_base',
#  'strw_scatter_offset',
#  'strw_scatter_shifted_offset',
#  'strd_scatter_base',
#  'strd_scatter_offset',
#  'strd_scatter_shifted_offset',
#  'brsr',
#  'qrshrnb',
#  'qrshrnt',
#  'qrshrunb',
#  'qrshrunt',
#  'qshrnb',
#  'qshrnt',
#  'qshrunb',
#  'qshrunt',
#  'rshrnb',
#  'rshrnt',
#  'shift_right_round',
#  'shrnb',
#  'shrnt',
#  'shift_right',
#  'shift_right_insert',
#  'shift_left_round_saturate',
#  'uqrshll',
#  'uqrshll_sat48',
#  'uqshll',
#  'uqrshl',
#  'shift_left_saturate',
#  'qshl_r',
#  'shift_left_unsigned_saturate',
#  'sqshll',
#  'uqshl',
#  'sqshl',
#  'shift_left_round',
#  'shlc',
#  'shllb',
#  'shllt',
#  'shift_left',
#  'shl_r',
#  'shift_left_insert',
#  'movlb',
#  'movlt',
#  'movnb',
#  'movnt',
#  'qmovnb',
#  'qmovnt',
#  'qmovunb',
#  'qmovunt',
#  'pnot',
#  'psel',
#  'ctp8',
#  'ctp16',
#  'ctp32',
#  'ctp64',
#  'lsll',
#  'asrl',
#  'sqrshrl',
#  'sqrshrl_sat48',
#  'sqrshr',
#  'urshrl',
#  'srshrl',
#  'urshr',
#  'srshr']

# %%
uniq_funcs = { f.decl:f for f in helium_int_funcs}.values() # uniquify (vshll_n duped for some reason)

# %%
funcs = uniq_funcs

# %%
from pprint import pprint

sorted_names = [
  f"{name_map[func.decoded.name]} : {func.decl}" for func in sorted(funcs) if "v7" in func.archs
]

name_args = {}
missing = {}
for func in funcs:
  args = ', '.join([str(arg) for arg in func.args])
  try:
    key = f"{name_map[func.decoded.name]}({args})"
  except KeyError:
    missing[func.decoded.name] = ''
    continue
  if key in name_args.keys():
    name_args[key] += [func]
  else:
    name_args[key] = [func]

pprint(missing)

needs_template = {k:v for (k,v) in name_args.items() if len(v) > 1}
needs_template_sig = needs_template.keys()
needs_template_funcs = [f for v in needs_template.values() for f in v]
# Out:
# {'abav': '',
#  'adc': '',
#  'adci': '',
#  'addlv': '',
#  'addlva': '',
#  'addv': '',
#  'addva': '',
#  'asrl': '',
#  'brsr': '',
#  'cmpcs': '',
#  'cmpeq': '',
#  'cmpge': '',
#  'cmpgt': '',
#  'cmphi': '',
#  'cmple': '',
#  'cmplt': '',
#  'cmpne': '',
#  'ctp16': '',
#  'ctp32': '',
#  'ctp64': '',
#  'ctp8': '',
#  'ddup': '',
#  'dwdup': '',
#  'hcadd_rot270': '',
#  'hcadd_rot90': '',
#  'idup': '',
#  'iwdup': '',
#  'ldrb': '',
#  'ldrb_gather_offset': '',
#  'ldrd_gather_base': '',
#  'ldrd_gather_offset': '',
#  'ldrd_gather_shifted_offset': '',
#  'ldrh': '',
#  'ldrh_gather_offset': '',
#  'ldrh_gather_shifted_offset': '',
#  'ldrw': '',
#  'ldrw_gather_base': '',
#  'ldrw_gather_offset': '',
#  'ldrw_gather_shifted_offset': '',
#  'lsll': '',
#  'maxa': '',
#  'maxav': '',
#  'maxv': '',
#  'mina': '',
#  'minav': '',
#  'minv': '',
#  'mladav': '',
#  'mladava': '',
#  'mladavax': '',
#  'mladavx': '',
#  'mlaldav': '',
#  'mlaldava': '',
#  'mlaldavax': '',
#  'mlaldavx': '',
#  'mlas': '',
#  'mlsdav': '',
#  'mlsdava': '',
#  'mlsdavax': '',
#  'mlsdavx': '',
#  'mlsldav': '',
#  'mlsldava': '',
#  'mlsldavax': '',
#  'mlsldavx': '',
#  'movlb': '',
#  'movlt': '',
#  'movnb': '',
#  'movnt': '',
#  'mulh': '',
#  'mullb_int': '',
#  'mullb_poly': '',
#  'mullt_int': '',
#  'mullt_poly': '',
#  'pnot': '',
#  'psel': '',
#  'qdmladh': '',
#  'qdmladhx': '',
#  'qdmlah': '',
#  'qdmlash': '',
#  'qdmlsdh': '',
#  'qdmlsdhx': '',
#  'qdmullb': '',
#  'qdmullt': '',
#  'qmovnb': '',
#  'qmovnt': '',
#  'qmovunb': '',
#  'qmovunt': '',
#  'qrdmladh': '',
#  'qrdmladhx': '',
#  'qrdmlah': '',
#  'qrdmlash': '',
#  'qrdmlsdh': '',
#  'qrdmlsdhx': '',
#  'qrshrnb': '',
#  'qrshrnt': '',
#  'qrshrunb': '',
#  'qrshrunt': '',
#  'qshl_r': '',
#  'qshrnb': '',
#  'qshrnt': '',
#  'qshrunb': '',
#  'qshrunt': '',
#  'rmlaldavh': '',
#  'rmlaldavha': '',
#  'rmlaldavhax': '',
#  'rmlaldavhx': '',
#  'rmlsldavh': '',
#  'rmlsldavha': '',
#  'rmlsldavhax': '',
#  'rmlsldavhx': '',
#  'rmulh': '',
#  'rshrnb': '',
#  'rshrnt': '',
#  'sbc': '',
#  'sbci': '',
#  'shl_r': '',
#  'shlc': '',
#  'shllb': '',
#  'shllt': '',
#  'shrnb': '',
#  'shrnt': '',
#  'sqrshr': '',
#  'sqrshrl': '',
#  'sqrshrl_sat48': '',
#  'sqshl': '',
#  'sqshll': '',
#  'srshr': '',
#  'srshrl': '',
#  'strb': '',
#  'strb_scatter_offset': '',
#  'strd_scatter_base': '',
#  'strd_scatter_offset': '',
#  'strd_scatter_shifted_offset': '',
#  'strh': '',
#  'strh_scatter_offset': '',
#  'strh_scatter_shifted_offset': '',
#  'strw': '',
#  'strw_scatter_base': '',
#  'strw_scatter_offset': '',
#  'strw_scatter_shifted_offset': '',
#  'uninitialized': '',
#  'uqrshl': '',
#  'uqrshll': '',
#  'uqrshll_sat48': '',
#  'uqshl': '',
#  'uqshll': '',
#  'urshr': '',
#  'urshrl': ''}

# %%
blacklist = [
  "move_high_narrow",
  "multiply_add_fused",
  "multiply_subtract_fused"
]

no_constexpr = [
  "load1",
  "load2",
  "load3",
  "load4",
  "load1_duplicate",
  "load2_duplicate",
  "load3_duplicate",
  "load4_duplicate",
  "load1_x2",
  "load1_x3",
  "load1_x4",
  "store1",
  "store2",
  "store3",
  "store4",
  "store1_x2",
  "store1_x3",
  "store1_x4",
]

always_inline = "[[gnu::always_inline]] "

def simplify_type(type):
  parts = type.split('x')
  return parts[0] + "_v"

def generate_function(func):
  args = ', '.join([str(arg) for arg in func.args])
  arg_idents = ', '.join([arg.ident.replace('*','') for arg in func.args])
  definition = "template <> " if func in needs_template_funcs else ""
  definition += always_inline
  definition += "nce " if func.name not in no_constexpr else "inline "
  definition += f"{func.return_type} {func.name}({args}) {{ return {func.intrinsic}({arg_idents}); }}"
  return definition

def generate_templated_function(func):
  args = ', '.join([str(arg) for arg in func.args])
  arg_idents = ', '.join([arg.ident.replace('*','') for arg in func.args])
  const_name = func.const
  args = args.replace(f', const int {const_name}', '')
  definition = f"template <int {const_name}>"
  definition += always_inline
  definition += f"nce {func.return_type} {func.name}({args}) {{ return {func.intrinsic}({arg_idents}, {const_name}); }}"
  return definition

# %%
#with open('neon.hpp', 'w') as sys.stdout:
print('#pragma once')
print('#include <arm_mve.h>')
print('#ifdef __cplusplus')
print('''#ifdef __clang__
#define nce constexpr
#else
#define nce inline
#endif
''')
print('namespace helium {')
print('// clang-format off')
for (name_arg, func_list) in needs_template.items():
  print(f"template <typename T> nce T {name_arg};")
for func in sorted(funcs):
  if func.name not in blacklist:
    if func.const != None:
      out = generate_templated_function(func)
    else:
      out = generate_function(func)
    print(out)
print('// clang-format on')
print('}  // namespace helium')
print('#endif')
# Out:
# #pragma once
# #include <arm_mve.h>
# #ifdef __cplusplus
# #ifdef __clang__
# #define nce constexpr
# #else
# #define nce inline
# #endif
#
# namespace helium {
# // clang-format off
# template <typename T> nce T create(uint64_t a, uint64_t b);
# [[gnu::always_inline]] nce uint8x16_t reverse_16bit(uint8x16_t inactive, uint8x16_t a, mve_pred16_t p) { return vrev16q_m_u8(inactive, a, p); }
# [[gnu::always_inline]] nce uint8x16_t reverse_32bit(uint8x16_t inactive, uint8x16_t a, mve_pred16_t p) { return vrev32q_m_u8(inactive, a, p); }
# [[gnu::always_inline]] nce uint8x16_t reverse_64bit(uint8x16_t inactive, uint8x16_t a, mve_pred16_t p) { return vrev64q_m_u8(inactive, a, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpeq(uint8x16_t a, uint8x16_t b) { return vcmpeqq_u8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpeq(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcmpeqq_m_u8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpne(uint8x16_t a, uint8x16_t b) { return vcmpneq_u8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpne(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcmpneq_m_u8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpcs(uint8x16_t a, uint8x16_t b) { return vcmpcsq_u8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpcs(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcmpcsq_m_u8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmphi(uint8x16_t a, uint8x16_t b) { return vcmphiq_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t min(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vminq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t max(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmaxq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_abs(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vabdq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vaddq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmphi(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcmphiq_m_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t min(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vminq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t max(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmaxq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_abs(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vabdq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vaddq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add(uint8x16_t inactive, uint8x16_t a, uint8_t b, mve_pred16_t p) { return vaddq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t mina(uint8x16_t a, int8x16_t b) { return vminaq_s8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t mina(uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vminaq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t maxa(uint8x16_t a, int8x16_t b) { return vmaxaq_s8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t maxa(uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vmaxaq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t reverse_16bit(uint8x16_t a, mve_pred16_t p) { return vrev16q_x_u8(a, p); }
# [[gnu::always_inline]] nce uint8x16_t reverse_32bit(uint8x16_t a, mve_pred16_t p) { return vrev32q_x_u8(a, p); }
# [[gnu::always_inline]] nce uint8x16_t reverse_64bit(uint8x16_t a, mve_pred16_t p) { return vrev64q_x_u8(a, p); }
# [[gnu::always_inline]] nce uint8x16_t ddup(uint8x16_t inactive, uint32_t a, const int imm, mve_pred16_t p) { return vddupq_m_n_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t ddup(uint8x16_t inactive, uint32_t *a, const int imm, mve_pred16_t p) { return vddupq_m_wb_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t dwdup(uint8x16_t inactive, uint32_t a, uint32_t b, const int imm, mve_pred16_t p) { return vdwdupq_m_n_u8(inactive, a, b, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t dwdup(uint8x16_t inactive, uint32_t *a, uint32_t b, const int imm, mve_pred16_t p) { return vdwdupq_m_wb_u8(inactive, a, b, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t idup(uint8x16_t inactive, uint32_t a, const int imm, mve_pred16_t p) { return vidupq_m_n_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t idup(uint8x16_t inactive, uint32_t *a, const int imm, mve_pred16_t p) { return vidupq_m_wb_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t iwdup(uint8x16_t inactive, uint32_t a, uint32_t b, const int imm, mve_pred16_t p) { return viwdupq_m_n_u8(inactive, a, b, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t iwdup(uint8x16_t inactive, uint32_t *a, uint32_t b, const int imm, mve_pred16_t p) { return viwdupq_m_wb_u8(inactive, a, b, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t duplicate(uint8x16_t inactive, uint8_t a, mve_pred16_t p) { return vdupq_m_n_u8(inactive, a, p); }
# [[gnu::always_inline]] nce uint8x16_t uninitialized(uint8x16_t t) { return vuninitializedq(t); }
# [[gnu::always_inline]] nce mve_pred16_t cmpeq(uint8x16_t a, uint8_t b) { return vcmpeqq_n_u8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpeq(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vcmpeqq_m_n_u8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpne(uint8x16_t a, uint8_t b) { return vcmpneq_n_u8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpne(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vcmpneq_m_n_u8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpcs(uint8x16_t a, uint8_t b) { return vcmpcsq_n_u8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpcs(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vcmpcsq_m_n_u8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmphi(uint8x16_t a, uint8_t b) { return vcmphiq_n_u8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmphi(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vcmphiq_m_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add(uint8x16_t a, uint8_t b) { return vaddq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t add(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vaddq_x_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint32_t addv(uint8x16_t a) { return vaddvq_u8(a); }
# [[gnu::always_inline]] nce uint8x16_t add_halve(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vhaddq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add_halve_round(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vrhaddq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add_saturate(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vqaddq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add_halve(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vhaddq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add_halve_round(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vrhaddq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add_halve(uint8x16_t inactive, uint8x16_t a, uint8_t b, mve_pred16_t p) { return vhaddq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add_saturate(uint8x16_t inactive, uint8x16_t a, uint8_t b, mve_pred16_t p) { return vqaddq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t mulh(uint8x16_t a, uint8x16_t b) { return vmulhq_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t mulh(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmulhq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t mulh(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmulhq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t mullb_poly(uint8x16_t a, uint8x16_t b) { return vmullbq_poly_p8(a, b); }
# [[gnu::always_inline]] nce uint16x8_t mullb_int(uint8x16_t a, uint8x16_t b) { return vmullbq_int_u8(a, b); }
# [[gnu::always_inline]] nce uint16x8_t mullb_poly(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmullbq_poly_x_p8(a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t mullb_int(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmullbq_int_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t mullt_poly(uint8x16_t a, uint8x16_t b) { return vmulltq_poly_p8(a, b); }
# [[gnu::always_inline]] nce uint16x8_t mullt_int(uint8x16_t a, uint8x16_t b) { return vmulltq_int_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t multiply(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmulq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t rmulh(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vrmulhq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t mullt_poly(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmulltq_poly_x_p8(a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t mullt_int(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmulltq_int_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t multiply(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vmulq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t rmulh(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vrmulhq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t multiply(uint8x16_t inactive, uint8x16_t a, uint8_t b, mve_pred16_t p) { return vmulq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t rmulh(uint8x16_t a, uint8x16_t b) { return vrmulhq_u8(a, b); }
# [[gnu::always_inline]] nce uint32_t mladav(uint8x16_t m1, uint8x16_t m2) { return vmladavq_u8(m1, m2); }
# [[gnu::always_inline]] nce uint8x16_t subtract(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vsubq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_high(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vhsubq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_saturate(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vqsubq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_clear(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vbicq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_and(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vandq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_xor(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return veorq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_or_not(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vornq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_or(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vorrq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint32_t mladav(uint8x16_t m1, uint8x16_t m2, mve_pred16_t p) { return vmladavq_p_u8(m1, m2, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vsubq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_high(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vhsubq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t count_leading_zero_bits(uint8x16_t inactive, uint8x16_t a, mve_pred16_t p) { return vclzq_m_u8(inactive, a, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_clear(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vbicq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_and(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vandq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_xor(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return veorq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_not(uint8x16_t inactive, uint8x16_t a, mve_pred16_t p) { return vmvnq_m_u8(inactive, a, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_or_not(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vornq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_or(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vorrq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t multiply_add(uint8x16_t add, uint8x16_t m1, uint8_t m2) { return vmlaq_n_u8(add, m1, m2); }
# [[gnu::always_inline]] nce uint8x16_t multiply_add(uint8x16_t add, uint8x16_t m1, uint8_t m2, mve_pred16_t p) { return vmlaq_m_n_u8(add, m1, m2, p); }
# [[gnu::always_inline]] nce uint8x16_t mlas(uint8x16_t m1, uint8x16_t m2, uint8_t add) { return vmlasq_n_u8(m1, m2, add); }
# [[gnu::always_inline]] nce uint8x16_t mlas(uint8x16_t m1, uint8x16_t m2, uint8_t add, mve_pred16_t p) { return vmlasq_m_n_u8(m1, m2, add, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract(uint8x16_t inactive, uint8x16_t a, uint8_t b, mve_pred16_t p) { return vsubq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_high(uint8x16_t inactive, uint8x16_t a, uint8_t b, mve_pred16_t p) { return vhsubq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_saturate(uint8x16_t inactive, uint8x16_t a, uint8_t b, mve_pred16_t p) { return vqsubq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t complex_add_rotate_90(uint8x16_t a, uint8x16_t b) { return vcaddq_rot90_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t complex_add_rotate_270(uint8x16_t a, uint8x16_t b) { return vcaddq_rot270_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t complex_add_rotate_90(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcaddq_rot90_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t complex_add_rotate_270(uint8x16_t inactive, uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcaddq_rot270_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_round_saturate(uint8x16_t inactive, uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vqrshlq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_saturate(uint8x16_t inactive, uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vqshlq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_round(uint8x16_t inactive, uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vrshlq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left(uint8x16_t inactive, uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vshlq_m_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t complex_add_rotate_90(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcaddq_rot90_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t complex_add_rotate_270(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vcaddq_rot270_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t psel(uint8x16_t a, uint8x16_t b, mve_pred16_t p) { return vpselq_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t brsr(uint8x16_t inactive, uint8x16_t a, int32_t b, mve_pred16_t p) { return vbrsrq_m_n_u8(inactive, a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_right_round(uint8x16_t inactive, uint8x16_t a, const int imm, mve_pred16_t p) { return vrshrq_m_n_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_right(uint8x16_t inactive, uint8x16_t a, const int imm, mve_pred16_t p) { return vshrq_m_n_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_right_insert(uint8x16_t a, uint8x16_t b, const int imm, mve_pred16_t p) { return vsriq_m_n_u8(a, b, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_saturate(uint8x16_t inactive, uint8x16_t a, const int imm, mve_pred16_t p) { return vqshlq_m_n_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_round(uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vrshlq_x_u8(a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t movlb(uint8x16_t a, mve_pred16_t p) { return vmovlbq_x_u8(a, p); }
# [[gnu::always_inline]] nce uint16x8_t movlt(uint8x16_t a) { return vmovltq_u8(a); }
# [[gnu::always_inline]] nce uint8x16_t movnb(uint8x16_t a, uint16x8_t b) { return vmovnbq_u16(a, b); }
# [[gnu::always_inline]] nce uint8x16_t movnb(uint8x16_t a, uint16x8_t b, mve_pred16_t p) { return vmovnbq_m_u16(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t movnt(uint8x16_t a, uint16x8_t b) { return vmovntq_u16(a, b); }
# [[gnu::always_inline]] nce uint8x16_t movnt(uint8x16_t a, uint16x8_t b, mve_pred16_t p) { return vmovntq_m_u16(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t qmovnb(uint8x16_t a, uint16x8_t b) { return vqmovnbq_u16(a, b); }
# [[gnu::always_inline]] nce uint8x16_t qmovnb(uint8x16_t a, uint16x8_t b, mve_pred16_t p) { return vqmovnbq_m_u16(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t qmovnt(uint8x16_t a, uint16x8_t b) { return vqmovntq_u16(a, b); }
# [[gnu::always_inline]] nce uint8x16_t qmovnt(uint8x16_t a, uint16x8_t b, mve_pred16_t p) { return vqmovntq_m_u16(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t qmovunb(uint8x16_t a, int16x8_t b) { return vqmovunbq_s16(a, b); }
# [[gnu::always_inline]] nce uint8x16_t qmovunb(uint8x16_t a, int16x8_t b, mve_pred16_t p) { return vqmovunbq_m_s16(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t qmovunt(uint8x16_t a, int16x8_t b) { return vqmovuntq_s16(a, b); }
# [[gnu::always_inline]] nce uint8x16_t qmovunt(uint8x16_t a, int16x8_t b, mve_pred16_t p) { return vqmovuntq_m_s16(a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t movlt(uint8x16_t a, mve_pred16_t p) { return vmovltq_x_u8(a, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_round(uint8x16_t a, int32_t b, mve_pred16_t p) { return vrshlq_m_n_u8(a, b, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t shlc(uint8x16_t a, uint32_t *b) { return vshlcq_u8(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t shlc(uint8x16_t a, uint32_t *b, const int imm, mve_pred16_t p) { return vshlcq_m_u8(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint16x8_t shllb(uint8x16_t a) { return vshllbq_n_u8(a, imm); }
# [[gnu::always_inline]] nce uint16x8_t shllb(uint8x16_t a, const int imm, mve_pred16_t p) { return vshllbq_x_n_u8(a, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint16x8_t shllt(uint8x16_t a) { return vshlltq_n_u8(a, imm); }
# [[gnu::always_inline]] nce uint8x16_t shift_left(uint8x16_t a, int8x16_t b, mve_pred16_t p) { return vshlq_x_u8(a, b, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t shift_left(uint8x16_t a) { return vshlq_n_u8(a, imm); }
# [[gnu::always_inline]] nce uint8x16_t shift_left(uint8x16_t inactive, uint8x16_t a, const int imm, mve_pred16_t p) { return vshlq_m_n_u8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_insert(uint8x16_t a, uint8x16_t b, const int imm, mve_pred16_t p) { return vsliq_m_n_u8(a, b, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_unsigned_saturate(uint8x16_t inactive, int8x16_t a, const int imm, mve_pred16_t p) { return vqshluq_m_n_s8(inactive, a, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qrshrnb(uint8x16_t a, uint16x8_t b) { return vqrshrnbq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qrshrnb(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vqrshrnbq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qrshrnt(uint8x16_t a, uint16x8_t b) { return vqrshrntq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qrshrnt(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vqrshrntq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qshrnb(uint8x16_t a, uint16x8_t b) { return vqshrnbq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qshrnb(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vqshrnbq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qshrnt(uint8x16_t a, uint16x8_t b) { return vqshrntq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qshrnt(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vqshrntq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t rshrnb(uint8x16_t a, uint16x8_t b) { return vrshrnbq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t rshrnb(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vrshrnbq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t rshrnt(uint8x16_t a, uint16x8_t b) { return vrshrntq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t rshrnt(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vrshrntq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t shrnb(uint8x16_t a, uint16x8_t b) { return vshrnbq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t shrnb(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vshrnbq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t shrnt(uint8x16_t a, uint16x8_t b) { return vshrntq_n_u16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t shrnt(uint8x16_t a, uint16x8_t b, const int imm, mve_pred16_t p) { return vshrntq_m_n_u16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qrshrunb(uint8x16_t a, int16x8_t b) { return vqrshrunbq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qrshrunb(uint8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqrshrunbq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qrshrunt(uint8x16_t a, int16x8_t b) { return vqrshruntq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qrshrunt(uint8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqrshruntq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qshrunb(uint8x16_t a, int16x8_t b) { return vqshrunbq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qshrunb(uint8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqshrunbq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t qshrunt(uint8x16_t a, int16x8_t b) { return vqshruntq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce uint8x16_t qshrunt(uint8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqshruntq_m_n_s16(a, b, imm, p); }
# [[gnu::always_inline]] nce uint32_t addv(uint8x16_t a, mve_pred16_t p) { return vaddvq_p_u8(a, p); }
# [[gnu::always_inline]] nce uint8x16_t count_leading_zero_bits(uint8x16_t a, mve_pred16_t p) { return vclzq_x_u8(a, p); }
# [[gnu::always_inline]] nce uint8x16_t bitwise_not(uint8x16_t a, mve_pred16_t p) { return vmvnq_x_u8(a, p); }
# [[gnu::always_inline]] nce uint8x16_t add_halve(uint8x16_t a, uint8_t b) { return vhaddq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t add_halve(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vhaddq_x_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t add_saturate(uint8x16_t a, uint8_t b) { return vqaddq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t multiply(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vmulq_x_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract(uint8x16_t a, uint8_t b) { return vsubq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t subtract(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vsubq_x_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_high(uint8x16_t a, uint8_t b) { return vhsubq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t subtract_high(uint8x16_t a, uint8_t b, mve_pred16_t p) { return vhsubq_x_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t subtract_saturate(uint8x16_t a, uint8_t b) { return vqsubq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t brsr(uint8x16_t a, int32_t b) { return vbrsrq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t brsr(uint8x16_t a, int32_t b, mve_pred16_t p) { return vbrsrq_x_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_right_round(uint8x16_t a, const int imm, mve_pred16_t p) { return vrshrq_x_n_u8(a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_right(uint8x16_t a, const int imm, mve_pred16_t p) { return vshrq_x_n_u8(a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_round_saturate(uint8x16_t a, int32_t b) { return vqrshlq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_round_saturate(uint8x16_t a, int32_t b, mve_pred16_t p) { return vqrshlq_m_n_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t qshl_r(uint8x16_t a, int32_t b) { return vqshlq_r_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t qshl_r(uint8x16_t a, int32_t b, mve_pred16_t p) { return vqshlq_m_r_u8(a, b, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left_round(uint8x16_t a, int32_t b) { return vrshlq_n_u8(a, b); }
# [[gnu::always_inline]] nce uint16x8_t shllt(uint8x16_t a, const int imm, mve_pred16_t p) { return vshlltq_x_n_u8(a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shift_left(uint8x16_t a, const int imm, mve_pred16_t p) { return vshlq_x_n_u8(a, imm, p); }
# [[gnu::always_inline]] nce uint8x16_t shl_r(uint8x16_t a, int32_t b) { return vshlq_r_u8(a, b); }
# [[gnu::always_inline]] nce uint8x16_t shl_r(uint8x16_t a, int32_t b, mve_pred16_t p) { return vshlq_m_r_u8(a, b, p); }
# [[gnu::always_inline]] nce uint16x8_t movlb(uint8x16_t a) { return vmovlbq_u8(a); }
# [[gnu::always_inline]] nce int8x16_t reverse_16bit(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vrev16q_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t reverse_32bit(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vrev32q_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t reverse_64bit(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vrev64q_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpeq(int8x16_t a, int8x16_t b) { return vcmpeqq_s8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpne(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcmpneq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpge(int8x16_t a, int8x16_t b) { return vcmpgeq_s8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpge(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcmpgeq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpgt(int8x16_t a, int8x16_t b) { return vcmpgtq_s8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmpgt(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcmpgtq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t reverse_64bit(int8x16_t a, mve_pred16_t p) { return vrev64q_x_s8(a, p); }
# [[gnu::always_inline]] nce int8x16_t uninitialized(int8x16_t t) { return vuninitializedq(t); }
# [[gnu::always_inline]] nce mve_pred16_t cmpeq(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcmpeqq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmpne(int8x16_t a, int8x16_t b) { return vcmpneq_s8(a, b); }
# [[gnu::always_inline]] nce mve_pred16_t cmple(int8x16_t a, int8x16_t b) { return vcmpleq_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t min(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vminq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmple(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcmpleq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmplt(int8x16_t a, int8x16_t b) { return vcmpltq_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t max(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmaxq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract_abs(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vabdq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vaddq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add_halve(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhaddq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add_halve_round(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vrhaddq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add_saturate(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqaddq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add_halve(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhaddq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add_halve_round(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vrhaddq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add_halve(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vhaddq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add_saturate(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vqaddq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t mulh(int8x16_t a, int8x16_t b) { return vmulhq_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t mulh(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmulhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t mulh(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmulhq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int16x8_t mullb_int(int8x16_t a, int8x16_t b) { return vmullbq_int_s8(a, b); }
# [[gnu::always_inline]] nce int16x8_t mullb_int(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmullbq_int_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int16x8_t mullt_int(int8x16_t a, int8x16_t b) { return vmulltq_int_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t multiply(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmulq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t rmulh(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vrmulhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qdmladh(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqdmladhq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qdmladh(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqdmladhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qdmladhx(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqdmladhxq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qdmladhx(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqdmladhxq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qrdmladh(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqrdmladhq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qrdmladh(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqrdmladhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qrdmladhx(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqrdmladhxq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qrdmladhx(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqrdmladhxq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int16x8_t mullt_int(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmulltq_int_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t multiply(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmulq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t rmulh(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vrmulhq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t multiply(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vmulq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t rmulh(int8x16_t a, int8x16_t b) { return vrmulhq_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t qdmlsdh(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqdmlsdhq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qdmlsdh(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqdmlsdhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qdmlsdhx(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqdmlsdhxq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qdmlsdhx(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqdmlsdhxq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qrdmlsdh(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqrdmlsdhq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qrdmlsdh(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqrdmlsdhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qrdmlsdhx(int8x16_t inactive, int8x16_t a, int8x16_t b) { return vqrdmlsdhxq_s8(inactive, a, b); }
# [[gnu::always_inline]] nce int8x16_t qrdmlsdhx(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqrdmlsdhxq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t multiply_double_saturate_high(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqdmulhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t multiply_double_round_saturate_high(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqrdmulhq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t cmplt(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcmpltq_m_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t min(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vminq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t max(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmaxq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract_abs(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vabdq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t abs(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vabsq_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t abs_saturate(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vqabsq_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t add(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vaddq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qrdmlash(int8x16_t m1, int8x16_t m2, int8_t add) { return vqrdmlashq_n_s8(m1, m2, add); }
# [[gnu::always_inline]] nce int8x16_t qrdmlash(int8x16_t m1, int8x16_t m2, int8_t add, mve_pred16_t p) { return vqrdmlashq_m_n_s8(m1, m2, add, p); }
# [[gnu::always_inline]] nce int8x16_t multiply_double_saturate_high(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vqdmulhq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t multiply_double_saturate_high(int8x16_t a, int8x16_t b) { return vqdmulhq_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t multiply_double_round_saturate_high(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vqrdmulhq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t multiply_double_round_saturate_high(int8x16_t a, int8x16_t b) { return vqrdmulhq_s8(a, b); }
# [[gnu::always_inline]] nce int32_t mladav(int8x16_t m1, int8x16_t m2) { return vmladavq_s8(m1, m2); }
# [[gnu::always_inline]] nce int32_t mladav(int8x16_t m1, int8x16_t m2, mve_pred16_t p) { return vmladavq_p_s8(m1, m2, p); }
# [[gnu::always_inline]] nce int32_t mladavx(int8x16_t m1, int8x16_t m2) { return vmladavxq_s8(m1, m2); }
# [[gnu::always_inline]] nce int32_t mladavx(int8x16_t m1, int8x16_t m2, mve_pred16_t p) { return vmladavxq_p_s8(m1, m2, p); }
# [[gnu::always_inline]] nce int32_t mlsdav(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmlsdavq_p_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t add(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vaddq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t multiply_add(int8x16_t add, int8x16_t m1, int8_t m2) { return vmlaq_n_s8(add, m1, m2); }
# [[gnu::always_inline]] nce int8x16_t multiply_add(int8x16_t add, int8x16_t m1, int8_t m2, mve_pred16_t p) { return vmlaq_m_n_s8(add, m1, m2, p); }
# [[gnu::always_inline]] nce int8x16_t mlas(int8x16_t m1, int8x16_t m2, int8_t add) { return vmlasq_n_s8(m1, m2, add); }
# [[gnu::always_inline]] nce int8x16_t mlas(int8x16_t m1, int8x16_t m2, int8_t add, mve_pred16_t p) { return vmlasq_m_n_s8(m1, m2, add, p); }
# [[gnu::always_inline]] nce int32_t mlsdav(int8x16_t a, int8x16_t b) { return vmlsdavq_s8(a, b); }
# [[gnu::always_inline]] nce int32_t mlsdavx(int8x16_t a, int8x16_t b) { return vmlsdavxq_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t subtract(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vsubq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract_high(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhsubq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract_saturate(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqsubq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_clear(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vbicq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_and(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vandq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_xor(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return veorq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_or_not(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vornq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_or(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vorrq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t complex_add_rotate_270(int8x16_t a, int8x16_t b) { return vcaddq_rot270_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t complex_add_rotate_90(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcaddq_rot90_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t complex_add_rotate_270(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcaddq_rot270_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t hcadd_rot90(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhcaddq_rot90_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t complex_add_rotate_90(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcaddq_rot90_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t complex_add_rotate_270(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vcaddq_rot270_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t hcadd_rot90(int8x16_t a, int8x16_t b) { return vhcaddq_rot90_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t hcadd_rot90(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhcaddq_rot90_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t hcadd_rot270(int8x16_t a, int8x16_t b) { return vhcaddq_rot270_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t hcadd_rot270(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhcaddq_rot270_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int32_t mlsdavx(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vmlsdavxq_p_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vsubq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract_high(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhsubq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t count_leading_sign_bits(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vclsq_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t count_leading_zero_bits(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vclzq_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_clear(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vbicq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t negate(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vnegq_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t negate_saturate(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vqnegq_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_and(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vandq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_xor(int8x16_t a, int8x16_t b, mve_pred16_t p) { return veorq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_not(int8x16_t inactive, int8x16_t a, mve_pred16_t p) { return vmvnq_m_s8(inactive, a, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_or_not(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vornq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t bitwise_or(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vorrq_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t hcadd_rot270(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vhcaddq_rot270_x_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vsubq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract_high(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vhsubq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t subtract_saturate(int8x16_t inactive, int8x16_t a, int8_t b, mve_pred16_t p) { return vqsubq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t complex_add_rotate_90(int8x16_t a, int8x16_t b) { return vcaddq_rot90_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t shift_left_round_saturate(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqrshlq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t shift_left_saturate(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vqshlq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t brsr(int8x16_t inactive, int8x16_t a, int32_t b, mve_pred16_t p) { return vbrsrq_m_n_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t shift_right_round(int8x16_t inactive, int8x16_t a, const int imm, mve_pred16_t p) { return vrshrq_m_n_s8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce int8x16_t shift_right(int8x16_t inactive, int8x16_t a, const int imm, mve_pred16_t p) { return vshrq_m_n_s8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce int8x16_t shift_right_insert(int8x16_t a, int8x16_t b, const int imm, mve_pred16_t p) { return vsriq_m_n_s8(a, b, imm, p); }
# [[gnu::always_inline]] nce int8x16_t shift_left_saturate(int8x16_t inactive, int8x16_t a, const int imm, mve_pred16_t p) { return vqshlq_m_n_s8(inactive, a, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t qrshrnb(int8x16_t a, int16x8_t b) { return vqrshrnbq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t qrshrnb(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqrshrnbq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t qrshrnt(int8x16_t a, int16x8_t b) { return vqrshrntq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t qrshrnt(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqrshrntq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t qshrnb(int8x16_t a, int16x8_t b) { return vqshrnbq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t qshrnb(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqshrnbq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t qshrnt(int8x16_t a, int16x8_t b) { return vqshrntq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t qshrnt(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vqshrntq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t rshrnb(int8x16_t a, int16x8_t b) { return vrshrnbq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t rshrnb(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vrshrnbq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t rshrnt(int8x16_t a, int16x8_t b) { return vrshrntq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t rshrnt(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vrshrntq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t shrnb(int8x16_t a, int16x8_t b) { return vshrnbq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t shrnb(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vshrnbq_m_n_s16(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t shrnt(int8x16_t a, int16x8_t b) { return vshrntq_n_s16(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t shrnt(int8x16_t a, int16x8_t b, const int imm, mve_pred16_t p) { return vshrntq_m_n_s16(a, b, imm, p); }
# [[gnu::always_inline]] nce int8x16_t brsr(int8x16_t a, int32_t b) { return vbrsrq_n_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t brsr(int8x16_t a, int32_t b, mve_pred16_t p) { return vbrsrq_x_n_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t shift_right_round(int8x16_t a, const int imm, mve_pred16_t p) { return vrshrq_x_n_s8(a, imm, p); }
# [[gnu::always_inline]] nce int8x16_t shift_right(int8x16_t a, const int imm, mve_pred16_t p) { return vshrq_x_n_s8(a, imm, p); }
# [[gnu::always_inline]] nce int8x16_t shift_left_round_saturate(int8x16_t a, int32_t b) { return vqrshlq_n_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t shift_left_round_saturate(int8x16_t a, int32_t b, mve_pred16_t p) { return vqrshlq_m_n_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qshl_r(int8x16_t a, int32_t b) { return vqshlq_r_s8(a, b); }
# [[gnu::always_inline]] nce int8x16_t qshl_r(int8x16_t a, int32_t b, mve_pred16_t p) { return vqshlq_m_r_s8(a, b, p); }
# template <int imm>[[gnu::always_inline]] nce uint8x16_t shift_left_unsigned_saturate(int8x16_t a) { return vqshluq_n_s8(a, imm); }
# [[gnu::always_inline]] nce int8x16_t shift_left_round(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vrshlq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t shift_left(int8x16_t inactive, int8x16_t a, int8x16_t b, mve_pred16_t p) { return vshlq_m_s8(inactive, a, b, p); }
# [[gnu::always_inline]] nce int8x16_t shift_left_round(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vrshlq_x_s8(a, b, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t shlc(int8x16_t a, uint32_t *b) { return vshlcq_s8(a, b, imm); }
# [[gnu::always_inline]] nce int8x16_t shlc(int8x16_t a, uint32_t *b, const int imm, mve_pred16_t p) { return vshlcq_m_s8(a, b, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int16x8_t shllb(int8x16_t a) { return vshllbq_n_s8(a, imm); }
# [[gnu::always_inline]] nce int16x8_t shllb(int8x16_t a, const int imm, mve_pred16_t p) { return vshllbq_x_n_s8(a, imm, p); }
# template <int imm>[[gnu::always_inline]] nce int16x8_t shllt(int8x16_t a) { return vshlltq_n_s8(a, imm); }
# [[gnu::always_inline]] nce int8x16_t shift_left(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vshlq_x_s8(a, b, p); }
# template <int imm>[[gnu::always_inline]] nce int8x16_t shift_left(int8x16_t a) { return vshlq_n_s8(a, imm); }
# [[gnu::always_inline]] nce int8x16_t shift_left(int8x16_t inactive, int8x16_t a, const int imm, mve_pred16_t p) { return vshlq_m_n_s8(inactive, a, imm, p); }
# [[gnu::always_inline]] nce int8x16_t shift_left_insert(int8x16_t a, int8x16_t b, const int imm, mve_pred16_t p) { return vsliq_m_n_s8(a, b, imm, p); }
# [[gnu::always_inline]] nce int16x8_t movlb(int8x16_t a, mve_pred16_t p) { return vmovlbq_x_s8(a, p); }
# [[gnu::always_inline]] nce int16x8_t movlt(int8x16_t a) { return vmovltq_s8(a); }
# [[gnu::always_inline]] nce int8x16_t psel(int8x16_t a, int8x16_t b, mve_pred16_t p) { return vpselq_s8(a, b, p); }
# [[gnu::always_inline]] nce int8x16_t qdmlah(int8x16_t add, int8x16_t m1, int8_t m2) { return vqdmlahq_n_s8(add, m1, m2); }
# [[gnu::always_inline]] nce int8x16_t qdmlah(int8x16_t add, int8x16_t m1, int8_t m2, mve_pred16_t p) { return vqdmlahq_m_n_s8(add, m1, m2, p); }
# [[gnu::always_inline]] nce int8x16_t qrdmlah(int8x16_t add, int8x16_t m1, int8_t m2) { return vqrdmlahq_n_s8(add, m1, m2); }
# ...
# [[gnu::always_inline]] nce uint64x2_t ldrd_gather_shifted_offset(uint64_t const *base, uint64x2_t offset) { return vldrdq_gather_shifted_offset_u64(base, offset); }
# [[gnu::always_inline]] nce int64x2_t ldrd_gather_shifted_offset(int64_t const *base, uint64x2_t offset, mve_pred16_t p) { return vldrdq_gather_shifted_offset_z_s64(base, offset, p); }
# [[gnu::always_inline]] nce uint64x2_t ldrd_gather_shifted_offset(uint64_t const *base, uint64x2_t offset, mve_pred16_t p) { return vldrdq_gather_shifted_offset_z_u64(base, offset, p); }
# [[gnu::always_inline]] inline void store2(int8_t *addr, int8x16x2_t value) { return vst2q_s8(addr, value); }
# [[gnu::always_inline]] inline void store2(int16_t *addr, int16x8x2_t value) { return vst2q_s16(addr, value); }
# [[gnu::always_inline]] inline void store2(int32_t *addr, int32x4x2_t value) { return vst2q_s32(addr, value); }
# [[gnu::always_inline]] inline void store2(uint8_t *addr, uint8x16x2_t value) { return vst2q_u8(addr, value); }
# [[gnu::always_inline]] inline void store2(uint16_t *addr, uint16x8x2_t value) { return vst2q_u16(addr, value); }
# [[gnu::always_inline]] inline void store2(uint32_t *addr, uint32x4x2_t value) { return vst2q_u32(addr, value); }
# [[gnu::always_inline]] inline void store4(int8_t *addr, int8x16x4_t value) { return vst4q_s8(addr, value); }
# [[gnu::always_inline]] inline void store4(int16_t *addr, int16x8x4_t value) { return vst4q_s16(addr, value); }
# [[gnu::always_inline]] inline void store4(int32_t *addr, int32x4x4_t value) { return vst4q_s32(addr, value); }
# [[gnu::always_inline]] inline void store4(uint8_t *addr, uint8x16x4_t value) { return vst4q_u8(addr, value); }
# [[gnu::always_inline]] inline void store4(uint16_t *addr, uint16x8x4_t value) { return vst4q_u16(addr, value); }
# [[gnu::always_inline]] inline void store4(uint32_t *addr, uint32x4x4_t value) { return vst4q_u32(addr, value); }
# [[gnu::always_inline]] inline void store1(int8_t *base, int8x16_t value, mve_pred16_t p) { return vst1q_p_s8(base, value, p); }
# [[gnu::always_inline]] inline void store1(int16_t *base, int16x8_t value, mve_pred16_t p) { return vst1q_p_s16(base, value, p); }
# [[gnu::always_inline]] inline void store1(int32_t *base, int32x4_t value, mve_pred16_t p) { return vst1q_p_s32(base, value, p); }
# [[gnu::always_inline]] inline void store1(uint8_t *base, uint8x16_t value, mve_pred16_t p) { return vst1q_p_u8(base, value, p); }
# [[gnu::always_inline]] inline void store1(uint16_t *base, uint16x8_t value, mve_pred16_t p) { return vst1q_p_u16(base, value, p); }
# [[gnu::always_inline]] inline void store1(uint32_t *base, uint32x4_t value, mve_pred16_t p) { return vst1q_p_u32(base, value, p); }
# [[gnu::always_inline]] nce void strb(int8_t *base, int8x16_t value) { return vstrbq_s8(base, value); }
# [[gnu::always_inline]] nce void strb(int8_t *base, int16x8_t value) { return vstrbq_s16(base, value); }
# [[gnu::always_inline]] nce void strb(int8_t *base, int32x4_t value) { return vstrbq_s32(base, value); }
# [[gnu::always_inline]] nce void strb(uint8_t *base, uint8x16_t value) { return vstrbq_u8(base, value); }
# [[gnu::always_inline]] nce void strb(uint8_t *base, uint16x8_t value) { return vstrbq_u16(base, value); }
# [[gnu::always_inline]] nce void strb(uint8_t *base, uint32x4_t value) { return vstrbq_u32(base, value); }
# [[gnu::always_inline]] nce void strb(int8_t *base, int8x16_t value, mve_pred16_t p) { return vstrbq_p_s8(base, value, p); }
# [[gnu::always_inline]] nce void strb(int8_t *base, int16x8_t value, mve_pred16_t p) { return vstrbq_p_s16(base, value, p); }
# [[gnu::always_inline]] nce void strb(int8_t *base, int32x4_t value, mve_pred16_t p) { return vstrbq_p_s32(base, value, p); }
# [[gnu::always_inline]] nce void strb(uint8_t *base, uint8x16_t value, mve_pred16_t p) { return vstrbq_p_u8(base, value, p); }
# [[gnu::always_inline]] nce void strb(uint8_t *base, uint16x8_t value, mve_pred16_t p) { return vstrbq_p_u16(base, value, p); }
# [[gnu::always_inline]] nce void strb(uint8_t *base, uint32x4_t value, mve_pred16_t p) { return vstrbq_p_u32(base, value, p); }
# [[gnu::always_inline]] nce void strh(int16_t *base, int16x8_t value) { return vstrhq_s16(base, value); }
# [[gnu::always_inline]] nce void strh(int16_t *base, int32x4_t value) { return vstrhq_s32(base, value); }
# [[gnu::always_inline]] nce void strh(uint16_t *base, uint16x8_t value) { return vstrhq_u16(base, value); }
# [[gnu::always_inline]] nce void strh(uint16_t *base, uint32x4_t value) { return vstrhq_u32(base, value); }
# [[gnu::always_inline]] nce void strh(int16_t *base, int16x8_t value, mve_pred16_t p) { return vstrhq_p_s16(base, value, p); }
# [[gnu::always_inline]] nce void strh(int16_t *base, int32x4_t value, mve_pred16_t p) { return vstrhq_p_s32(base, value, p); }
# [[gnu::always_inline]] nce void strh(uint16_t *base, uint16x8_t value, mve_pred16_t p) { return vstrhq_p_u16(base, value, p); }
# [[gnu::always_inline]] nce void strh(uint16_t *base, uint32x4_t value, mve_pred16_t p) { return vstrhq_p_u32(base, value, p); }
# [[gnu::always_inline]] nce void strw(int32_t *base, int32x4_t value) { return vstrwq_s32(base, value); }
# [[gnu::always_inline]] nce void strw(uint32_t *base, uint32x4_t value) { return vstrwq_u32(base, value); }
# [[gnu::always_inline]] nce void strw(int32_t *base, int32x4_t value, mve_pred16_t p) { return vstrwq_p_s32(base, value, p); }
# [[gnu::always_inline]] nce void strw(uint32_t *base, uint32x4_t value, mve_pred16_t p) { return vstrwq_p_u32(base, value, p); }
# [[gnu::always_inline]] nce void strb_scatter_offset(int8_t *base, uint8x16_t offset, int8x16_t value) { return vstrbq_scatter_offset_s8(base, offset, value); }
# [[gnu::always_inline]] nce void strb_scatter_offset(int8_t *base, uint16x8_t offset, int16x8_t value) { return vstrbq_scatter_offset_s16(base, offset, value); }
# [[gnu::always_inline]] nce void strb_scatter_offset(int8_t *base, uint32x4_t offset, int32x4_t value) { return vstrbq_scatter_offset_s32(base, offset, value); }
# [[gnu::always_inline]] nce void strb_scatter_offset(uint8_t *base, uint8x16_t offset, uint8x16_t value) { return vstrbq_scatter_offset_u8(base, offset, value); }
# [[gnu::always_inline]] nce void strb_scatter_offset(uint8_t *base, uint16x8_t offset, uint16x8_t value) { return vstrbq_scatter_offset_u16(base, offset, value); }
# [[gnu::always_inline]] nce void strb_scatter_offset(uint8_t *base, uint32x4_t offset, uint32x4_t value) { return vstrbq_scatter_offset_u32(base, offset, value); }
# [[gnu::always_inline]] nce void strb_scatter_offset(int8_t *base, uint8x16_t offset, int8x16_t value, mve_pred16_t p) { return vstrbq_scatter_offset_p_s8(base, offset, value, p); }
# [[gnu::always_inline]] nce void strb_scatter_offset(int8_t *base, uint16x8_t offset, int16x8_t value, mve_pred16_t p) { return vstrbq_scatter_offset_p_s16(base, offset, value, p); }
# [[gnu::always_inline]] nce void strb_scatter_offset(int8_t *base, uint32x4_t offset, int32x4_t value, mve_pred16_t p) { return vstrbq_scatter_offset_p_s32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strb_scatter_offset(uint8_t *base, uint8x16_t offset, uint8x16_t value, mve_pred16_t p) { return vstrbq_scatter_offset_p_u8(base, offset, value, p); }
# [[gnu::always_inline]] nce void strb_scatter_offset(uint8_t *base, uint16x8_t offset, uint16x8_t value, mve_pred16_t p) { return vstrbq_scatter_offset_p_u16(base, offset, value, p); }
# [[gnu::always_inline]] nce void strb_scatter_offset(uint8_t *base, uint32x4_t offset, uint32x4_t value, mve_pred16_t p) { return vstrbq_scatter_offset_p_u32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_offset(int16_t *base, uint16x8_t offset, int16x8_t value) { return vstrhq_scatter_offset_s16(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_offset(int16_t *base, uint32x4_t offset, int32x4_t value) { return vstrhq_scatter_offset_s32(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_offset(uint16_t *base, uint16x8_t offset, uint16x8_t value) { return vstrhq_scatter_offset_u16(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_offset(uint16_t *base, uint32x4_t offset, uint32x4_t value) { return vstrhq_scatter_offset_u32(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_offset(int16_t *base, uint16x8_t offset, int16x8_t value, mve_pred16_t p) { return vstrhq_scatter_offset_p_s16(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_offset(int16_t *base, uint32x4_t offset, int32x4_t value, mve_pred16_t p) { return vstrhq_scatter_offset_p_s32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_offset(uint16_t *base, uint16x8_t offset, uint16x8_t value, mve_pred16_t p) { return vstrhq_scatter_offset_p_u16(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_offset(uint16_t *base, uint32x4_t offset, uint32x4_t value, mve_pred16_t p) { return vstrhq_scatter_offset_p_u32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(int16_t *base, uint16x8_t offset, int16x8_t value) { return vstrhq_scatter_shifted_offset_s16(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(int16_t *base, uint32x4_t offset, int32x4_t value) { return vstrhq_scatter_shifted_offset_s32(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(uint16_t *base, uint16x8_t offset, uint16x8_t value) { return vstrhq_scatter_shifted_offset_u16(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(uint16_t *base, uint32x4_t offset, uint32x4_t value) { return vstrhq_scatter_shifted_offset_u32(base, offset, value); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(int16_t *base, uint16x8_t offset, int16x8_t value, mve_pred16_t p) { return vstrhq_scatter_shifted_offset_p_s16(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(int16_t *base, uint32x4_t offset, int32x4_t value, mve_pred16_t p) { return vstrhq_scatter_shifted_offset_p_s32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(uint16_t *base, uint16x8_t offset, uint16x8_t value, mve_pred16_t p) { return vstrhq_scatter_shifted_offset_p_u16(base, offset, value, p); }
# [[gnu::always_inline]] nce void strh_scatter_shifted_offset(uint16_t *base, uint32x4_t offset, uint32x4_t value, mve_pred16_t p) { return vstrhq_scatter_shifted_offset_p_u32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strw_scatter_offset(int32_t *base, uint32x4_t offset, int32x4_t value) { return vstrwq_scatter_offset_s32(base, offset, value); }
# [[gnu::always_inline]] nce void strw_scatter_offset(uint32_t *base, uint32x4_t offset, uint32x4_t value) { return vstrwq_scatter_offset_u32(base, offset, value); }
# [[gnu::always_inline]] nce void strw_scatter_offset(int32_t *base, uint32x4_t offset, int32x4_t value, mve_pred16_t p) { return vstrwq_scatter_offset_p_s32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strw_scatter_offset(uint32_t *base, uint32x4_t offset, uint32x4_t value, mve_pred16_t p) { return vstrwq_scatter_offset_p_u32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strw_scatter_shifted_offset(int32_t *base, uint32x4_t offset, int32x4_t value) { return vstrwq_scatter_shifted_offset_s32(base, offset, value); }
# [[gnu::always_inline]] nce void strw_scatter_shifted_offset(uint32_t *base, uint32x4_t offset, uint32x4_t value) { return vstrwq_scatter_shifted_offset_u32(base, offset, value); }
# [[gnu::always_inline]] nce void strw_scatter_shifted_offset(int32_t *base, uint32x4_t offset, int32x4_t value, mve_pred16_t p) { return vstrwq_scatter_shifted_offset_p_s32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strw_scatter_shifted_offset(uint32_t *base, uint32x4_t offset, uint32x4_t value, mve_pred16_t p) { return vstrwq_scatter_shifted_offset_p_u32(base, offset, value, p); }
# [[gnu::always_inline]] nce void strd_scatter_offset(int64_t *base, uint64x2_t offset, int64x2_t value) { return vstrdq_scatter_offset_s64(base, offset, value); }
# [[gnu::always_inline]] nce void strd_scatter_offset(uint64_t *base, uint64x2_t offset, uint64x2_t value) { return vstrdq_scatter_offset_u64(base, offset, value); }
# [[gnu::always_inline]] nce void strd_scatter_offset(int64_t *base, uint64x2_t offset, int64x2_t value, mve_pred16_t p) { return vstrdq_scatter_offset_p_s64(base, offset, value, p); }
# [[gnu::always_inline]] nce void strd_scatter_offset(uint64_t *base, uint64x2_t offset, uint64x2_t value, mve_pred16_t p) { return vstrdq_scatter_offset_p_u64(base, offset, value, p); }
# [[gnu::always_inline]] nce void strd_scatter_shifted_offset(int64_t *base, uint64x2_t offset, int64x2_t value) { return vstrdq_scatter_shifted_offset_s64(base, offset, value); }
# [[gnu::always_inline]] nce void strd_scatter_shifted_offset(uint64_t *base, uint64x2_t offset, uint64x2_t value) { return vstrdq_scatter_shifted_offset_u64(base, offset, value); }
# [[gnu::always_inline]] nce void strd_scatter_shifted_offset(int64_t *base, uint64x2_t offset, int64x2_t value, mve_pred16_t p) { return vstrdq_scatter_shifted_offset_p_s64(base, offset, value, p); }
# [[gnu::always_inline]] nce void strd_scatter_shifted_offset(uint64_t *base, uint64x2_t offset, uint64x2_t value, mve_pred16_t p) { return vstrdq_scatter_shifted_offset_p_u64(base, offset, value, p); }
# [[gnu::always_inline]] nce uint64_t uqrshll(uint64_t value, int32_t shift) { return uqrshll(value, shift); }
# [[gnu::always_inline]] nce uint64_t uqrshll_sat48(uint64_t value, int32_t shift) { return uqrshll_sat48(value, shift); }
# template <int shift>[[gnu::always_inline]] nce uint64_t uqshll(uint64_t value) { return uqshll(value, shift); }
# [[gnu::always_inline]] nce uint32_t uqrshl(uint32_t value, int32_t shift) { return uqrshl(value, shift); }
# template <int shift>[[gnu::always_inline]] nce int64_t sqshll(int64_t value) { return sqshll(value, shift); }
# template <int shift>[[gnu::always_inline]] nce uint32_t uqshl(uint32_t value) { return uqshl(value, shift); }
# template <int shift>[[gnu::always_inline]] nce int32_t sqshl(int32_t value) { return sqshl(value, shift); }
# [[gnu::always_inline]] nce int64x2_t psel(int64x2_t a, int64x2_t b, mve_pred16_t p) { return vpselq_s64(a, b, p); }
# [[gnu::always_inline]] nce mve_pred16_t ctp8(uint32_t a) { return vctp8q(a); }
# [[gnu::always_inline]] nce mve_pred16_t ctp16(uint32_t a) { return vctp16q(a); }
# [[gnu::always_inline]] nce mve_pred16_t ctp32(uint32_t a) { return vctp32q(a); }
# [[gnu::always_inline]] nce mve_pred16_t ctp64(uint32_t a) { return vctp64q(a); }
# [[gnu::always_inline]] nce mve_pred16_t ctp8(uint32_t a, mve_pred16_t p) { return vctp8q_m(a, p); }
# [[gnu::always_inline]] nce mve_pred16_t ctp16(uint32_t a, mve_pred16_t p) { return vctp16q_m(a, p); }
# [[gnu::always_inline]] nce mve_pred16_t ctp32(uint32_t a, mve_pred16_t p) { return vctp32q_m(a, p); }
# [[gnu::always_inline]] nce mve_pred16_t ctp64(uint32_t a, mve_pred16_t p) { return vctp64q_m(a, p); }
# [[gnu::always_inline]] nce uint64_t lsll(uint64_t value, int32_t shift) { return lsll(value, shift); }
# [[gnu::always_inline]] nce int64_t asrl(int64_t value, int32_t shift) { return asrl(value, shift); }
# [[gnu::always_inline]] nce int64_t sqrshrl(int64_t value, int32_t shift) { return sqrshrl(value, shift); }
# [[gnu::always_inline]] nce int64_t sqrshrl_sat48(int64_t value, int32_t shift) { return sqrshrl_sat48(value, shift); }
# [[gnu::always_inline]] nce int32_t sqrshr(int32_t value, int32_t shift) { return sqrshr(value, shift); }
# template <int shift>[[gnu::always_inline]] nce uint64_t urshrl(uint64_t value) { return urshrl(value, shift); }
# template <int shift>[[gnu::always_inline]] nce int64_t srshrl(int64_t value) { return srshrl(value, shift); }
# template <int shift>[[gnu::always_inline]] nce uint32_t urshr(uint32_t value) { return urshr(value, shift); }
# template <int shift>[[gnu::always_inline]] nce int32_t srshr(int32_t value) { return srshr(value, shift); }
# // clang-format on
# }  // namespace helium
# #endif
